# %% [markdown]
# ![image.png](attachment:f479f356-94a5-41b6-8153-08446c660e1b.png)

# %% [markdown]
# # RIDGE AND LASSO REGRESSION

# %% [markdown]
# ![image.png](attachment:75b7f5a7-6d0f-4a0b-8c79-646e47516a22.png)

# %% [markdown]
# ![image.png](attachment:b1741553-2eb2-4c5e-8bdb-f73703f01f75.png)

# %% [markdown]
# ![image.png](attachment:6d280161-abe9-48be-b96a-f3ee07b72436.png)

# %% [markdown]
# ![image.png](attachment:cdc52325-7cf5-466a-ae82-9c0a1910905e.png)

# %% [markdown]
# ![image.png](attachment:b0c49515-b6c8-420a-b36b-339b8a5ec234.png)
