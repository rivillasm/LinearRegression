# %% [markdown]
# ![image.png](attachment:e0d1790e-71bf-461e-9fb9-1ea9b0788e86.png)

# %% [markdown]
# # KMEANS CLUSTERING - UNSUPERVISED

# %% [markdown]
# ![image.png](attachment:ecd5744f-6dc7-42c9-baa1-18c2048dd803.png)

# %% [markdown]
# ![image.png](attachment:235269d3-db85-4f85-a7d1-0ecf8bc0a152.png)

# %% [markdown]
# * initialize centroid and find the distance of each point to that centroid
# * uses eucledial or manhatan algoritm
# * assign the closest point to each centroid
# * a new summation for all the assigned points is performed and the average is computed to update the centroid locations
# * calcualted the the distances again and reasign the points to the nearest centroid

# %% [markdown]
# ![image.png](attachment:e83ce48b-bbbc-466d-9b3d-8f485e234e87.png)

# %% [markdown]
# * elbow method to decide the K value  -  K VALUE OPTIMIZATION
# * WCSS WITHING CLUSTER SUM OF SQUARE
#
# ![image.png](attachment:8a522bdb-e502-4978-a4e0-a1c87c04bcc9.png)
#
# * when initializing the centroids - make sure to set them appart to each other, therefore use kmeans ++

# %% [markdown]
# # HERARCHICAL CLUSTERING

# %% [markdown]
# ![image.png](attachment:db3bf329-73e1-4617-98f3-6d712a5bc582.png)
#
# * find the longest vertical line that does not have horizontal line past to it

# %% [markdown]
# ![image.png](attachment:20bd2f8d-61a5-41a7-a8d4-4c2e6c83e643.png)
#
# * hirerchichal clustering takes more time the kmeans
# * dataset is large go with kmeans
#
# ### validating clustering models:    Silhouette(clustering)

# %% [markdown]
# ![image.png](attachment:7a4d3f8b-695e-4aed-9ab2-bbdb504f4354.png)
#
# * the closes to +1 the better
# * zero means the model requires improvement
#
# https://www.youtube.com/watch?v=_jg1UFoef1c
#
# ![image.png](attachment:897f0d3e-5f52-4765-9b9a-97ea2bb8ca11.png)

# %% [markdown]
# # DB SCAN - CLUSTERING

# %% [markdown]
# * Very useful to leave outliers separated
#
# ![image.png](attachment:1b7cd2fc-47d4-478f-bca9-377fdbc4a93c.png)

# %% [markdown]
# * MINPOINTS - HYPERPARAMETER
# * EPSILON - radious
# * NOISE POINTS - TREATED AS OUTLIER
#
# ![image.png](attachment:bdba1f89-3f04-4592-b624-86d8fd1327ae.png)
